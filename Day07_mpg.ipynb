# %% [markdown]
# ### 자동차 연비 데이터  정제
#
# uci repo
# url : https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/
#
# * requests 패키지 이용 데이터 로딩.
# * 최대한 많이 정제
# * 배기량, 연비

# %%
import math

def mean(num_list): # 평균
    return sum(num_list) / len(num_list)

def median(num_list): # 중앙값
    num_list.sort()
    if len(num_list) % 2 == 1:
        i = len(num_list) // 2
        return num_list[i]
    else:
        i = len(num_list) // 2
        return (num_list[i] + num_list[i - 1]) / 2

def dev(num_list): # 편차
    m = mean(num_list)
    return [x - m for x in num_list]

def var(num_list): # 분산
    n = len(num_list)
    d = dev(num_list)
    return sum([x * x for x in d]) / (n - 1)

def stdev(num_list): # 표준편차
    return math.sqrt(var(num_list))

def covar(list_1, list_2):  # 공분산
    n = len(list_1)
    list_1_dev = dev(list_1)
    list_2_dev = dev(list_2)
    return sum(x * y for x, y in zip(list_1_dev, list_2_dev)) / (n - 1)

def corel(list_1, list_2):  # 상관도 (-1 ~ 1)
    return covar(list_1, list_2) / (stdev(list_1) * stdev(list_2))

# %%
import requests

x = requests.get('https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data')

# %%
pass1 = x.text.split('\n')    # by-line
#print(len(pass1))

pass2 = []                    # 각 샘플(줄)별 숫자부분, 차명 부분 분리 .split('\t')
for line in pass1: 
    pass2.append(line.split('\t'))
    
pass3 = []                    # 숫자 부분 분리 .split()
for e in pass2:
    try:
        y = e[0].split()
        y.append(e[1])
        pass3.append(y)
    except:
        pass

print(pass3)
# Out:
# [['18.0', '8', '307.0', '130.0', '3504.', '12.0', '70', '1', '"chevrolet chevelle malibu"'], ['15.0', '8', '350.0', '165.0', '3693.', '11.5', '70', '1', '"buick skylark 320"'], ['18.0', '8', '318.0', '150.0', '3436.', '11.0', '70', '1', '"plymouth satellite"'], ['16.0', '8', '304.0', '150.0', '3433.', '12.0', '70', '1', '"amc rebel sst"'], ['17.0', '8', '302.0', '140.0', '3449.', '10.5', '70', '1', '"ford torino"'], ['15.0', '8', '429.0', '198.0', '4341.', '10.0', '70', '1', '"ford galaxie 500"'], ['14.0', '8', '454.0', '220.0', '4354.', '9.0', '70', '1', '"chevrolet impala"'], ['14.0', '8', '440.0', '215.0', '4312.', '8.5', '70', '1', '"plymouth fury iii"'], ['14.0', '8', '455.0', '225.0', '4425.', '10.0', '70', '1', '"pontiac catalina"'], ['15.0', '8', '390.0', '190.0', '3850.', '8.5', '70', '1', '"amc ambassador dpl"'], ['15.0', '8', '383.0', '170.0', '3563.', '10.0', '70', '1', '"dodge challenger se"'], ['14.0', '8', '340.0', '160.0', '3609.', '8.0', '70', '1', '"plymouth \'cuda 
# ...

# %%
# float으로 형변환, 차명 " 제거
for e in pass3:
    for i, n in enumerate(e[:-1]):
        try:
            e[i] = float(n)
        except:
            print(n)
            e[i] = 0.0
        e[-1] = e[-1].strip('"')
print(pass3)
# Out:
# [[18.0, 8.0, 307.0, 130.0, 3504.0, 12.0, 70.0, 1.0, 'chevrolet chevelle malibu'], [15.0, 8.0, 350.0, 165.0, 3693.0, 11.5, 70.0, 1.0, 'buick skylark 320'], [18.0, 8.0, 318.0, 150.0, 3436.0, 11.0, 70.0, 1.0, 'plymouth satellite'], [16.0, 8.0, 304.0, 150.0, 3433.0, 12.0, 70.0, 1.0, 'amc rebel sst'], [17.0, 8.0, 302.0, 140.0, 3449.0, 10.5, 70.0, 1.0, 'ford torino'], [15.0, 8.0, 429.0, 198.0, 4341.0, 10.0, 70.0, 1.0, 'ford galaxie 500'], [14.0, 8.0, 454.0, 220.0, 4354.0, 9.0, 70.0, 1.0, 'chevrolet impala'], [14.0, 8.0, 440.0, 215.0, 4312.0, 8.5, 70.0, 1.0, 'plymouth fury iii'], [14.0, 8.0, 455.0, 225.0, 4425.0, 10.0, 70.0, 1.0, 'pontiac catalina'], [15.0, 8.0, 390.0, 190.0, 3850.0, 8.5, 70.0, 1.0, 'amc ambassador dpl'], [15.0, 8.0, 383.0, 170.0, 3563.0, 10.0, 70.0, 1.0, 'dodge challenger se'], [14.0, 8.0, 340.0, 160.0, 3609.0, 8.0, 70.0, 1.0, "plymouth 'cuda 340"], [15.0, 8.0, 400.0, 150.0, 3761.0, 9.5, 70.0, 1.0, 'chevrolet monte carlo'], [14.0, 8.0, 455.0, 225.0, 3086.0, 10.0, 70.0, 1.0
# ...

# %%
mpg_lsit = []                  # 연비
disp_list = []                 # 배기량

for e in pass3:
    mpg_lsit.append(e[0])
    disp_list.append(e[2])

# %%
# 연비   : 평균, 표준편차
# 배기량 : 평균, 표준편차

print('연비의 평균 : \t\t', mean(mpg_lsit))
print('연비의 표준편차 : \t', stdev(mpg_lsit))
print('배기량의 평균 : \t', mean(disp_list))
print('배기량의 표준편차 : \t', stdev(disp_list))
# Out:
# 연비의 평균 : 		 23.514572864321615
# 연비의 표준편차 : 	 7.815984312565782
# 배기량의 평균 : 	 193.42587939698493
# 배기량의 표준편차 : 	 104.26983817119581

# %%
print('상관도', corel(mpg_lsit, disp_list))
# Out:
# 상관도 -0.8042028248058988

# %%
# 연비 vs. 차체중량(인덱스 4)
weight_list = [e[4] for e in pass3]

print('상관도', corel(mpg_lsit, weight_list))
# Out:
# 상관도 -0.8317409332443351
