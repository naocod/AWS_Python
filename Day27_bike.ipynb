# %% [markdown]
# ### 분기별 부산시 이륜차 신고현황 2020.03 ~ 2023.01
#
# * 년도별 화재건수에 따른 피해자(사망/부상)
# * 지역별 재산피해 total / 부동산 / 동산
# *

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

current_font_list = matplotlib.rcParams['font.family']

font_path = "C:\Windows\Fonts\HMFMMUEX.TTC"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rcParams['font.family'] = [kfont] + current_font_list

pd_data_bike = pd.read_csv('이륜차신고현황_시도별_20230309171539.csv', encoding='cp949')
pd_data_person = pd.read_csv('행정구역_시군구_별_주민등록세대수_20230309172305.csv', encoding='cp949')
pd_data_bike.head()
# pd_data_person.head()
# print(pd_data.dtypes)
# Out:
#         시점  항목   금정구   기장군     남구    동구   동래구   부산진구    북구    사상구    사하구  \
# 0  2020.03  소계  8326  5342  10765  4372  8632  17356  8703  10262  11804
# 1  2020.03  경형   378   281    494   242   423    554   368    554    494
# 2  2020.03  소형  2307  1599   2775  1001  2399   5983  2416   3012   2935
# 3  2020.03  중형  5248  3117   6834  2912  5288   9950  5432   6291   7735
# 4  2020.03  대형   393   345    662   217   522    869   487    405    640
#
#      서구   수영구   연제구   영도구   해운대구
# 0  6093  6718  6801  6377  12703
# 1   203   306   273   207    569
# 2  1690  1892  1679  1584   3299
# 3  3975  4080  4387  4297   7887
# 4   225   440   462   289    948

# %%
pd_data_bike['연도'] = pd_data_bike['시점'].apply(lambda x:str(x).split('.')[0])
pd_data_bike['월'] = pd_data_bike['시점'].apply(lambda x:str(x).split('.')[1])

pd_data_bike.head()
# Out:
#         시점  항목   금정구   기장군     남구    동구   동래구   부산진구    북구    사상구    사하구  \
# 0  2020.03  소계  8326  5342  10765  4372  8632  17356  8703  10262  11804
# 1  2020.03  경형   378   281    494   242   423    554   368    554    494
# 2  2020.03  소형  2307  1599   2775  1001  2399   5983  2416   3012   2935
# 3  2020.03  중형  5248  3117   6834  2912  5288   9950  5432   6291   7735
# 4  2020.03  대형   393   345    662   217   522    869   487    405    640
#
#      서구   수영구   연제구   영도구   해운대구    연도   월
# 0  6093  6718  6801  6377  12703  2020  03
# 1   203   306   273   207    569  2020  03
# 2  1690  1892  1679  1584   3299  2020  03
# 3  3975  4080  4387  4297   7887  2020  03
# 4   225   440   462   289    948  2020  03
